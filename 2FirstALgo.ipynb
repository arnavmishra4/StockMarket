# %%
import pandas as pd 
from sqlalchemy import create_engine 
from binance.client import Client 
from binance import BinanceSocketManager

# %%
api_key = 'hN2hTSZKMy9nRbrVRckYOgSRH3nhZo2EmNiq0rCCN6WBAgHMu2sA8DjqIDyB8qqR'
secret = 'rgKjqvvWHR3wFjcmfXw2Tbn3KJ3rLeMIV9eQP2oQLRVG5syDcfECOlXBoQRKyWB8'

# %%
client = Client(api_key,secret)

# %%
engine = create_engine('sqlite:///D:\PersonalProjects/BitcoinStream.db')

# %%
data = pd.read_sql('BitcoinStream',engine)

# %%
data
# Out:
#                        Time     Price
# 0   2023-12-27 10:12:33.850  42713.07
# 1   2023-12-27 10:12:33.946  42713.07
# 2   2023-12-27 10:12:33.962  42713.06
# 3   2023-12-27 10:12:34.021  42713.06
# 4   2023-12-27 10:12:34.652  42713.06
# ..                      ...       ...
# 315 2023-12-27 10:33:14.865  43009.99
# 316 2023-12-27 10:33:15.563  43010.00
# 317 2023-12-27 10:33:39.587  43002.32
# 318 2023-12-27 10:33:50.776  43019.99
# 319 2023-12-27 10:34:13.435  43002.99
#
# [320 rows x 2 columns]

# %%
data.set_index('Time').plot()
# Out:
# <Axes: xlabel='Time'>
